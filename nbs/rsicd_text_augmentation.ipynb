# %%
! pip install transformers
! pip install sentencepiece
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.7/dist-packages (4.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.10.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers) (20.9)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.41.1)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from transformers) (4.6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers) (0.0.45)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.19.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.0.12)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from transformers) (3.13)
# Requirement already satisfied: huggingface-hub==0.0.12 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.0.12)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers) (2.4.7)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.4.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.7/dist-packages (0.1.96)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import json
from collections import Counter
import pandas as pd

# %%
with open("/content/drive/My Drive/rsicd/dataset_rsicd.json") as f:
    ds = json.load(f)

# %%
# Setting up the device for GPU usage

from torch import cuda
device = 'cuda' if cuda.is_available() else 'cpu'

# %%
# Storing tuples of image id and sentences in a list
all_sentences = []
for image in ds['images']:
    for sentence in image['sentences']:
        all_sentences.append((image['imgid'],sentence['raw']))

# %%
# Creating a counter to get counts of how many times each sentence was repeated in the same image
sentence_counts = dict(Counter(all_sentences))

# %%
# Converting the dictionary to a tuple -  (image_id, sentence, count)

image_id_sentences_and_counts = []
for sentence, count in sentence_counts.items():
    image_id_sentences_and_counts.append((sentence[0], sentence[1], count))

# %%
sentences_df = pd.DataFrame(image_id_sentences_and_counts, columns=['image_id', 'sentence', 'count'])

# %%
translation_languages_priority = ['fr','es','it', 'pt']

# %%
# Creating a dictionary with with languages to use for backtranslation
# eg. If the count = 2, one of them has to be backtranslated, and `fr` will be used for that.
languages_to_back_translate_with = {2 : translation_languages_priority[0],
                                    3 : translation_languages_priority[0:2],
                                    4 : translation_languages_priority[0:3],
                                    5 : translation_languages_priority}

# %%
# we dont need backtranslation if count = 1
sentences_df.drop(sentences_df[sentences_df['count'] == 1].index, inplace = True)

# %%
# Creating a column that has the languages to be used for running the backtranslation
sentences_df['languages_to_back_translate_with'] = sentences_df['count'].map(languages_to_back_translate_with)

# %%
# Creating a new row for each language
sentences_df = sentences_df.explode('languages_to_back_translate_with')

# %%
sentences_df = sentences_df.sort_values(by=['languages_to_back_translate_with'], ignore_index=True)

# %%
sentences_df.head()
# Out:
#    image_id  ... languages_to_back_translate_with
# 0      7525  ...                               es
# 1      2687  ...                               es
# 2      7228  ...                               es
# 3      2688  ...                               es
# 4      7227  ...                               es
#
# [5 rows x 4 columns]

# %% [markdown]
# ## Translation Model.

# %%
from transformers import MarianMTModel, MarianTokenizer

# %%
target_model_name = 'Helsinki-NLP/opus-mt-en-ROMANCE'
target_tokenizer = MarianTokenizer.from_pretrained(target_model_name)
target_model = MarianMTModel.from_pretrained(target_model_name)

# %%
en_model_name = 'Helsinki-NLP/opus-mt-ROMANCE-en'
en_tokenizer = MarianTokenizer.from_pretrained(en_model_name)
en_model = MarianMTModel.from_pretrained(en_model_name)

# %%
def translate(texts, model, tokenizer, language="fr"):
    # Prepare the text data into appropriate format for the model
    template = lambda text: f"{text}" if language == "en" else f">>{language}<< {text}"
    src_texts = [template(text) for text in texts]

    # Tokenize the texts
    encoded = tokenizer.prepare_seq2seq_batch(src_texts,return_tensors="pt")

    model.to(device)
    
    # Generate translation using model
    translated = model.generate(**encoded.to(device))

    # Convert the generated tokens indices back into text
    translated_texts = tokenizer.batch_decode(translated, skip_special_tokens=True)
    
    return translated_texts

# %%
def back_translate(texts, source_lang="en", target_lang="fr"):
    # Translate from source to target language
    fr_texts = translate(texts, target_model, target_tokenizer, 
                         language=target_lang)

    # Translate from target language back to source language
    back_translated_texts = translate(fr_texts, en_model, en_tokenizer, 
                                      language=source_lang)
    
    return back_translated_texts

# %%
# Group the dataframe by language to translate with, so that they can be batched together.
grouped_by_language = sentences_df.groupby(['languages_to_back_translate_with'])

# %%
list_of_dataframes_for_each_lang = []
for lang in translation_languages_priority:
  df = grouped_by_language.get_group(lang)
  sentences = list(df['sentence'])

  #Batch the sentences in groups of 64
  list_of_sentence_batches = [sentences[i:i + 64] for i in range(0, len(sentences), 64)]
  
  # list to store all translated sentences.
  translated_sentences = []

  for sentence_batch in list_of_sentence_batches:    
    batch_of_translated_sentences = back_translate(sentence_batch, target_lang = lang)
    translated_sentences += batch_of_translated_sentences
  df["back_translated_sentence"] = translated_sentences
  list_of_dataframes_for_each_lang.append(df)
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:3282: FutureWarning: `prepare_seq2seq_batch` is deprecated and will be removed in version 5 of 🤗 Transformers. Use the regular `__call__` method to prepare your inputs and the tokenizer under the `with_target_tokenizer` context manager to prepare your targets. See the documentation of your specific tokenizer for more details
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/torch/_tensor.py:575: UserWarning: floor_divide is deprecated, and will be removed in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values.
# To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor'). (Triggered internally at  /pytorch/aten/src/ATen/native/BinaryOps.cpp:467.)
#   return torch.floor_divide(self, other)
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:3282: FutureWarning: `prepare_seq2seq_batch` is deprecated and will be removed in version 5 of 🤗 Transformers. Use the regular `__call__` method to prepare your inputs and the tokenizer under the `with_target_tokenizer` context manager to prepare your targets. See the documentation of your specific tokenizer for more details
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app

# %%
sentences_with_translation_df = pd.concat(list_of_dataframes_for_each_lang, axis=0)

# %%
sentences_with_translation_df.head()
# Out:
#      image_id  ...                           back_translated_sentence
# 740       928  ...  seawater is so transparent that it looks like ...
# 741       584  ...         many cars parked on the side of the earth.
# 742       938  ...     a piece of green ocean is near a yellow beach.
# 743       570  ...      some plants are near a piece of kaki nueland.
# 744       599  ...         The bare earth has a small piece of water.
#
# [5 rows x 5 columns]

# %%
# Creating a copy of the original json, for augmentation.
text_augmented_ds = ds

# %%
def find_sentence_in_img(text, sentences):
  for sent_index, sentence in enumerate(sentences):
    print(f"{text} --AND-- {sentence['raw']}")
    print(text == sentence['raw'])
    if text == sentence['raw']:
      print(sent_index)
      return sent_index

# %%
for i,row in enumerate(sentences_with_translation_df.itertuples()):
  for image_index, image in enumerate(text_augmented_ds['images']):
    if image['imgid'] ==  row.image_id:
      sent_index = find_sentence_in_img(row.sentence, image['sentences'])
      print(f"image index = {image_index}")
      print(f"sent index = {sent_index}")
      text_augmented_ds['images'][image_index]['sentences'][sent_index]['raw'] = row.back_translated_sentence
# Out:
# Streaming output truncated to the last 5000 lines.
# False
# a white beach is near an ocean with many white waves . --AND-- a white beach is near an ocean with many white waves .
# True
# 3
# image index = 970
# sent index = 3
# it is a piece of gray bareland . --AND-- It's a gray naked piece of land.
# False
# it is a piece of gray bareland . --AND-- It's a piece of gray naked land.
# False
# it is a piece of gray bareland . --AND-- It's a gray naked piece of land.
# False
# it is a piece of gray bareland . --AND-- it is a piece of gray bareland .
# True
# 3
# image index = 498
# sent index = 3
# an airport is near some buildings and green trees . --AND-- an airport is located close to some buildings and green trees.
# False
# an airport is near some buildings and green trees . --AND-- an airport is close to some green buildings and trees.
# False
# an airport is near some buildings and green trees . --AND-- an airport is close to some green buildings and trees.
# False
# an airport is near some buildings and green trees . --AND-- an airport is near some buildings and green trees .
# True
# 3
# image index = 62
# sent index = 3
# it is a piece of bareland . --AND-- It's a piece of naked dirt.
# False
# it is a piece of bareland . --AND-- It's a piece of bare land.
# False
# it is a piece of bareland . --AND-- It's a piece of bare land.
# False
# it is a piece of bareland . --AND-- it is a piece of bareland .
# True
# 3
# image index = 409
# sent index = 3
# several long buildings and green trees are near a piece of bareland . --AND-- several long buildings and green trees are close to a bare piece of land.
# False
# several long buildings and green trees are near a piece of bareland . --AND-- several long buildings and green trees are close to a bare piece of land.
# False
# several long buildings and green trees are near a piece of bareland . --AND-- several long buildings and green trees are located near a bare piece of land.
# False
# several long buildings and green trees are near a piece of bareland . --AND-- several long buildings and green trees are near a piece of bareland .
# True
# 3
# image index = 451
# sent index = 3
# it is a piece of bareland . --AND-- It's a piece of naked dirt.
# False
# it is a piece of bareland . --AND-- It's a piece of bare land.
# False
# it is a piece of bareland . --AND-- It's a piece of bare land.
# False
# it is a piece of bareland . --AND-- it is a piece of bareland .
# True
# 3
# image index = 468
# sent index = 3
# some planes are parked in an airport . --AND-- some planes are parked in an airport.
# False
# some planes are parked in an airport . --AND-- Some planes are parked at an airport.
# False
# some planes are parked in an airport . --AND-- some planes are parked in an airport.
# False
# some planes are parked in an airport . --AND-- some planes are parked in an airport .
# True
# 3
# image index = 63
# sent index = 3
# it is a piece of khaki bareland . --AND-- It's a piece of kaki nueland.
# False
# it is a piece of khaki bareland . --AND-- It's a piece of khaki bareland.
# False
# it is a piece of khaki bareland . --AND-- It's a piece of khaki stripping.
# False
# it is a piece of khaki bareland . --AND-- it is a piece of khaki bareland .
# True
# 3
# image index = 532
# sent index = 3
# many planes are parked near a large building on an airport . --AND-- Many aircraft are parked near a large building on an airport.
# False
# many planes are parked near a large building on an airport . --AND-- Many planes are parked near a large building at an airport.
# False
# many planes are parked near a large building on an airport . --AND-- Many planes are parked near a large building on an airport.
# False
# many planes are parked near a large building on an airport . --AND-- many planes are parked near a large building on an airport .
# True
# 3
# image index = 3
# sent index = 3
# an ocean with white waves is near a beach with many rock mounds . --AND-- an ocean with white waves is near a beach with many rocky mounds.
# False
# an ocean with white waves is near a beach with many rock mounds . --AND-- an ocean with white waves is near a beach with many mounds of rock.
# False
# an ocean with white waves is near a beach with many rock mounds . --AND-- an ocean with white waves is close to a beach with many rock rams.
# False
# an ocean with white waves is near a beach with many rock mounds . --AND-- an ocean with white waves is near a beach with many rock mounds .
# True
# 3
# image index = 972
# sent index = 3
# several planes are in an airport near some buildings and green trees . --AND-- several planes are in an airport near some buildings and green trees.
# False
# several planes are in an airport near some buildings and green trees . --AND-- several planes are located in an airport near some buildings and green trees.
# False
# several planes are in an airport near some buildings and green trees . --AND-- Several planes are located in an airport near some green buildings and trees.
# False
# several planes are in an airport near some buildings and green trees . --AND-- several planes are in an airport near some buildings and green trees .
# True
# 3
# image index = 50
# sent index = 3
# a piece of green ocean is near a yellow beach . --AND-- a piece of green ocean is near a yellow beach.
# False
# a piece of green ocean is near a yellow beach . --AND-- a piece of green ocean is near a yellow beach.
# False
# a piece of green ocean is near a yellow beach . --AND-- a piece of green ocean is near a yellow beach.
# False
# a piece of green ocean is near a yellow beach . --AND-- a piece of green ocean is near a yellow beach .
# True
# 3
# image index = 937
# sent index = 3
# many planes are in an airport near some green trees . --AND-- Many aircraft are located in an airport near some green trees.
# False
# many planes are in an airport near some green trees . --AND-- Many planes are located in an airport near some green trees.
# False
# many planes are in an airport near some green trees . --AND-- Many planes are located in an airport near some green trees.
# False
# many planes are in an airport near some green trees . --AND-- many planes are in an airport near some green trees .
# True
# 3
# image index = 41
# sent index = 3
# waves in green ocean are near a yellow beach . --AND-- waves in the green ocean are near a yellow beach.
# False
# waves in green ocean are near a yellow beach . --AND-- waves in green ocean are near a yellow beach.
# False
# waves in green ocean are near a yellow beach . --AND-- waves in green ocean are near a yellow beach.
# False
# waves in green ocean are near a yellow beach . --AND-- waves in green ocean are near a yellow beach .
# True
# 3
# image index = 951
# sent index = 3
# a piece of bareland is near a river . --AND-- A piece of bare land is near a river.
# False
# a piece of bareland is near a river . --AND-- A piece of bare land is near a river.
# False
# a piece of bareland is near a river . --AND-- a piece of bare land is near a river.
# False
# a piece of bareland is near a river . --AND-- a piece of bareland is near a river .
# True
# 3
# image index = 435
# sent index = 3
# it is a piece of yellow bareland . --AND-- It's a piece of yellow bare land.
# False
# it is a piece of yellow bareland . --AND-- It's a piece of yellow naked land.
# False
# it is a piece of yellow bareland . --AND-- It's a piece of yellow stripe.
# False
# it is a piece of yellow bareland . --AND-- it is a piece of yellow bareland .
# True
# 3
# image index = 424
# sent index = 3
# an airport is near several farmlands and some buildings . --AND-- an airport is located close to several agricultural lands and certain buildings.
# False
# an airport is near several farmlands and some buildings . --AND-- an airport is close to several agricultural lands and some buildings.
# False
# an airport is near several farmlands and some buildings . --AND-- an airport is close to several agricultural land and some buildings.
# False
# an airport is near several farmlands and some buildings . --AND-- an airport is near several farmlands and some buildings .
# True
# 3
# image index = 36
# sent index = 3
# many small green spots are scattered in a piece of khaki bareland . --AND-- many small green spots are scattered in a piece of kaki nueland.
# False
# many small green spots are scattered in a piece of khaki bareland . --AND-- Many small green spots are scattered in a piece of naked khaki.
# False
# many small green spots are scattered in a piece of khaki bareland . --AND-- Many small green spots are scattered in a piece of khaki stripe.
# False
# many small green spots are scattered in a piece of khaki bareland . --AND-- many small green spots are scattered in a piece of khaki bareland .
# True
# 3
# image index = 504
# sent index = 3
# two rows of waves in green ocean are near a yellow beach . --AND-- two rows of waves in the green ocean are near a yellow beach.
# False
# two rows of waves in green ocean are near a yellow beach . --AND-- two rows of waves in the green ocean are located near a yellow beach.
# False
# two rows of waves in green ocean are near a yellow beach . --AND-- two rows of ocean green waves are located near a yellow beach.
# False
# two rows of waves in green ocean are near a yellow beach . --AND-- two rows of waves in green ocean are near a yellow beach .
# True
# 3
# image index = 959
# sent index = 3
# it is a piece of khaki bareland . --AND-- It's a piece of kaki nueland.
# False
# it is a piece of khaki bareland . --AND-- It's a piece of khaki bareland.
# False
# it is a piece of khaki bareland . --AND-- It's a piece of khaki stripping.
# False
# it is a piece of khaki bareland . --AND-- it is a piece of khaki bareland .
# True
# 3
# image index = 510
# sent index = 3
# several rows of white waves are near a yellow beach . --AND-- several rows of white waves are near a yellow beach.
# False
# several rows of white waves are near a yellow beach . --AND-- several rows of white waves are close to a yellow beach.
# False
# several rows of white waves are near a yellow beach . --AND-- different rows of white waves are located near a yellow beach.
# False
# several rows of white waves are near a yellow beach . --AND-- several rows of white waves are near a yellow beach .
# True
# 3
# image index = 950
# sent index = 3
# white waves in green ocean is next to yellow beach . --AND-- White waves in the green ocean is located next to the yellow beach.
# False
# white waves in green ocean is next to yellow beach . --AND-- White waves in the green ocean is next to the yellow beach.
# False
# white waves in green ocean is next to yellow beach . --AND-- White waves in green ocean is located next to the yellow beach.
# False
# white waves in green ocean is next to yellow beach . --AND-- white waves in green ocean is next to yellow beach .
# True
# 3
# image index = 979
# sent index = 3
# it is a piece of bareland . --AND-- It's a piece of naked dirt.
# False
# it is a piece of bareland . --AND-- It's a piece of bare land.
# False
# it is a piece of bareland . --AND-- It's a piece of bare land.
# False
# it is a piece of bareland . --AND-- it is a piece of bareland .
# True
# 3
# image index = 438
# sent index = 3
# a road is in a piece of yellow bareland . --AND-- a road is in a piece of yellow bare land.
# False
# a road is in a piece of yellow bareland . --AND-- a path is in a piece of yellow naked land.
# False
# a road is in a piece of yellow bareland . --AND-- a road is in a piece of yellow stripe.
# False
# a road is in a piece of yellow bareland . --AND-- a road is in a piece of yellow bareland .
# True
# 3
# image index = 488
# sent index = 3
# some planes are parked in an airport surrounded by green meadows and some trees . --AND-- some planes are parked in an airport surrounded by green meadows and some trees.
# False
# some planes are parked in an airport surrounded by green meadows and some trees . --AND-- some planes are parked in an airport surrounded by green meadows and some trees.
# False
# some planes are parked in an airport surrounded by green meadows and some trees . --AND-- some planes are parked in an airport surrounded by green meadows and some trees.
# False
# some planes are parked in an airport surrounded by green meadows and some trees . --AND-- some planes are parked in an airport surrounded by green meadows and some trees .
# True
# 3
# image index = 42
# sent index = 3
# a piece of beach is between an ocean with white waves and many green trees . --AND-- a piece of beach is between an ocean with white waves and many green trees.
# False
# a piece of beach is between an ocean with white waves and many green trees . --AND-- a piece of beach lies between an ocean with white waves and many green trees.
# False
# a piece of beach is between an ocean with white waves and many green trees . --AND-- a piece of beach is between an ocean with white waves and many green trees.
# False
# a piece of beach is between an ocean with white waves and many green trees . --AND-- a piece of beach is between an ocean with white waves and many green trees .
# True
# 3
# image index = 974
# sent index = 3
# a large piece of green ocean is near a beach . --AND-- a large piece of green ocean is near a beach.
# False
# a large piece of green ocean is near a beach . --AND-- a large piece of green ocean is near a beach.
# False
# a large piece of green ocean is near a beach . --AND-- a large piece of green ocean is near a beach.
# False
# a large piece of green ocean is near a beach . --AND-- a large piece of green ocean is near a beach .
# True
# 3
# image index = 949
# sent index = 3
# many white waves are in an ocean near a beach and some green trees . --AND-- many white waves are in an ocean near a beach and some green trees.
# False
# many white waves are in an ocean near a beach and some green trees . --AND-- many white waves are in an ocean near a beach and some green trees.
# False
# many white waves are in an ocean near a beach and some green trees . --AND-- Many white waves are in an ocean near a beach and some green trees.
# False
# many white waves are in an ocean near a beach and some green trees . --AND-- many white waves are in an ocean near a beach and some green trees .
# True
# 3
# image index = 980
# sent index = 3
# several wild roads are in a piece of yellow bareland . --AND-- several wild roads are in a piece of yellow bare land.
# False
# several wild roads are in a piece of yellow bareland . --AND-- Several wild roads are in a piece of yellow naked land.
# False
# several wild roads are in a piece of yellow bareland . --AND-- Several wild roads are in a piece of yellow locker room.
# False
# several wild roads are in a piece of yellow bareland . --AND-- several wild roads are in a piece of yellow bareland .
# True
# 3
# image index = 511
# sent index = 3
# it is a piece of bareland . --AND-- It's a piece of naked dirt.
# False
# it is a piece of bareland . --AND-- It's a piece of bare land.
# False
# it is a piece of bareland . --AND-- It's a piece of bare land.
# False
# it is a piece of bareland . --AND-- it is a piece of bareland .
# True
# 3
# image index = 423
# sent index = 3
# some planes are in an airport surrounded by many green trees . --AND-- Some aircraft are located in an airport surrounded by many green trees.
# False
# some planes are in an airport surrounded by many green trees . --AND-- some planes are located in an airport surrounded by many green trees.
# False
# some planes are in an airport surrounded by many green trees . --AND-- some planes are located in an airport surrounded by many green trees.
# False
# some planes are in an airport surrounded by many green trees . --AND-- some planes are in an airport surrounded by many green trees .
# True
# 3
# image index = 43
# sent index = 3
# white waves are between yellow beach and green ocean . --AND-- The white waves are between the yellow beach and the green ocean.
# False
# white waves are between yellow beach and green ocean . --AND-- the white waves are between the yellow beach and the green ocean.
# False
# white waves are between yellow beach and green ocean . --AND-- The white waves are between the yellow beach and the green ocean.
# False
# white waves are between yellow beach and green ocean . --AND-- white waves are between yellow beach and green ocean .
# True
# 3
# image index = 948
# sent index = 3
# some green meadows are in a piece of bareland . --AND-- Some green meadows are in a bare piece of land.
# False
# some green meadows are in a piece of bareland . --AND-- Some green meadows are in a bare piece of land.
# False
# some green meadows are in a piece of bareland . --AND-- Some green meadows are in a bare piece of land.
# False
# some green meadows are in a piece of bareland . --AND-- some green meadows are in a piece of bareland .
# True
# 3
# image index = 487
# sent index = 3
# some sparse plants are in a piece of bareland . --AND-- some rare plants are found in a piece of bare land.
# False
# some sparse plants are in a piece of bareland . --AND-- some scarce plants are found in a bare piece of land.
# False
# some sparse plants are in a piece of bareland . --AND-- Some scattered plants are in a bare piece of land.
# False
# some sparse plants are in a piece of bareland . --AND-- some sparse plants are in a piece of bareland .
# True
# 3
# image index = 428
# sent index = 3
# many white waves are in an ocean near a beach and some green trees . --AND-- many white waves are in an ocean near a beach and some green trees.
# False
# many white waves are in an ocean near a beach and some green trees . --AND-- many white waves are in an ocean near a beach and some green trees.
# False
# many white waves are in an ocean near a beach and some green trees . --AND-- Many white waves are in an ocean near a beach and some green trees.
# False
# many white waves are in an ocean near a beach and some green trees . --AND-- many white waves are in an ocean near a beach and some green trees .
# True
# 3
# image index = 981
# sent index = 3
# a piece of ocean is near a yellow beach . --AND-- a piece of ocean is near a yellow beach.
# False
# a piece of ocean is near a yellow beach . --AND-- a piece of ocean is near a yellow beach.
# False
# a piece of ocean is near a yellow beach . --AND-- a piece of ocean is near a yellow beach.
# False
# a piece of ocean is near a yellow beach . --AND-- a piece of ocean is near a yellow beach .
# True
# 3
# image index = 960
# sent index = 3
# many buildings are around some planes in an airport . --AND-- Many buildings are around some planes in an airport.
# False
# many buildings are around some planes in an airport . --AND-- Many buildings are around some planes at an airport.
# False
# many buildings are around some planes in an airport . --AND-- Many buildings are around some planes in an airport.
# False
# many buildings are around some planes in an airport . --AND-- many buildings are around some planes in an airport .
# True
# 3
# image index = 15
# sent index = 3
# some green plants are near a piece of khaki bareland . --AND-- some green plants are near a piece of kaki nueland.
# False
# some green plants are near a piece of khaki bareland . --AND-- Some green plants are close to a piece of naked khaki.
# False
# some green plants are near a piece of khaki bareland . --AND-- some green plants are close to a piece of khaki stripping.
# False
# some green plants are near a piece of khaki bareland . --AND-- some green plants are near a piece of khaki bareland .
# True
# 3
# image index = 489
# sent index = 3
# it is a piece of yellow bareland . --AND-- It's a piece of yellow bare land.
# False
# it is a piece of yellow bareland . --AND-- It's a piece of yellow naked land.
# False
# it is a piece of yellow bareland . --AND-- It's a piece of yellow stripe.
# False
# it is a piece of yellow bareland . --AND-- it is a piece of yellow bareland .
# True
# 3
# image index = 512
# sent index = 3
# a road is in a piece of khaki bareland . --AND-- a road is in a piece of kaki nueland.
# False
# a road is in a piece of khaki bareland . --AND-- a road is located in a piece of bare khaki land.
# False
# a road is in a piece of khaki bareland . --AND-- a road is in a piece of khaki strip.
# False
# a road is in a piece of khaki bareland . --AND-- a road is in a piece of khaki bareland .
# True
# 3
# image index = 509
# sent index = 3
# white waves in green ocean are near yellow beach and green plants . --AND-- White waves in the green ocean are near the yellow beach and green plants.
# False
# white waves in green ocean are near yellow beach and green plants . --AND-- the white waves in the green ocean are close to the yellow beach and green plants.
# False
# white waves in green ocean are near yellow beach and green plants . --AND-- white waves in green ocean are near yellow beach and green plants.
# False
# white waves in green ocean are near yellow beach and green plants . --AND-- white waves in green ocean are near yellow beach and green plants .
# True
# 3
# image index = 978
# sent index = 3
# some green plants are near a piece of bareland . --AND-- Some green plants are near a bare piece of land.
# False
# some green plants are near a piece of bareland . --AND-- Some green plants are near a bare piece of land.
# False
# some green plants are near a piece of bareland . --AND-- some green plants are near a bare piece of land.
# False
# some green plants are near a piece of bareland . --AND-- some green plants are near a piece of bareland .
# True
# 3
# image index = 436
# sent index = 3
# a piece of green ocean is near yellow beach and many green trees . --AND-- a piece of green ocean is near the yellow beach and many green trees.
# False
# a piece of green ocean is near yellow beach and many green trees . --AND-- a piece of green ocean is near the yellow beach and many green trees.
# False
# a piece of green ocean is near yellow beach and many green trees . --AND-- a piece of green ocean is near the yellow beach and many green trees.
# False
# a piece of green ocean is near yellow beach and many green trees . --AND-- a piece of green ocean is near yellow beach and many green trees .
# True
# 3
# image index = 976
# sent index = 3
# waves in green ocean are near a yellow beach . --AND-- waves in the green ocean are near a yellow beach.
# False
# waves in green ocean are near a yellow beach . --AND-- waves in green ocean are near a yellow beach.
# False
# waves in green ocean are near a yellow beach . --AND-- waves in green ocean are near a yellow beach.
# False
# waves in green ocean are near a yellow beach . --AND-- waves in green ocean are near a yellow beach .
# True
# 3
# image index = 956
# sent index = 3
# it is a piece of gray bareland . --AND-- It's a gray naked piece of land.
# False
# it is a piece of gray bareland . --AND-- It's a piece of gray naked land.
# False
# it is a piece of gray bareland . --AND-- It's a gray naked piece of land.
# False
# it is a piece of gray bareland . --AND-- it is a piece of gray bareland .
# True
# 3
# image index = 506
# sent index = 3
# white waves in a green ocean are near a yellow beach . --AND-- White waves in a green ocean are near a yellow beach.
# False
# white waves in a green ocean are near a yellow beach . --AND-- White waves in a green ocean are near a yellow beach.
# False
# white waves in a green ocean are near a yellow beach . --AND-- white waves in a green ocean are close to a yellow beach.
# False
# white waves in a green ocean are near a yellow beach . --AND-- white waves in a green ocean are near a yellow beach .
# True
# 3
# image index = 957
# sent index = 3
# several planes are parked in an airport near many green trees . --AND-- several planes are parked in an airport near many green trees.
# False
# several planes are parked in an airport near many green trees . --AND-- several planes are parked at an airport near many green trees.
# False
# several planes are parked in an airport near many green trees . --AND-- Several planes are parked in an airport near many green trees.
# False
# several planes are parked in an airport near many green trees . --AND-- several planes are parked in an airport near many green trees .
# True
# 3
# image index = 38
# sent index = 3
# it is a piece of bareland . --AND-- It's a piece of naked dirt.
# False
# it is a piece of bareland . --AND-- It's a piece of bare land.
# False
# it is a piece of bareland . --AND-- It's a piece of bare land.
# False
# it is a piece of bareland . --AND-- it is a piece of bareland .
# True
# 3
# image index = 426
# sent index = 3
# an ocean with white waves is near yellow beach . --AND-- an ocean with white waves is near the yellow beach.
# False
# an ocean with white waves is near yellow beach . --AND-- an ocean with white waves is near the yellow beach.
# False
# an ocean with white waves is near yellow beach . --AND-- an ocean with white waves is located near the yellow beach.
# False
# an ocean with white waves is near yellow beach . --AND-- an ocean with white waves is near yellow beach .
# True
# 3
# image index = 955
# sent index = 3
# it is a piece of khaki bareland . --AND-- It's a piece of kaki nueland.
# False
# it is a piece of khaki bareland . --AND-- It's a piece of khaki bareland.
# False
# it is a piece of khaki bareland . --AND-- It's a piece of khaki stripping.
# False
# it is a piece of khaki bareland . --AND-- it is a piece of khaki bareland .
# True
# 3
# image index = 491
# sent index = 3
# it is a piece of gray white bareland . --AND-- It's a piece of white gray nueland.
# False
# it is a piece of gray white bareland . --AND-- It's a piece of naked gray white.
# False
# it is a piece of gray white bareland . --AND-- It's a piece of white gray stripe.
# False
# it is a piece of gray white bareland . --AND-- it is a piece of gray white bareland .
# True
# 3
# image index = 507
# sent index = 3
# some planes are parked in an airport surrounded by green meadows and some trees . --AND-- some planes are parked in an airport surrounded by green meadows and some trees.
# False
# some planes are parked in an airport surrounded by green meadows and some trees . --AND-- some planes are parked in an airport surrounded by green meadows and some trees.
# False
# some planes are parked in an airport surrounded by green meadows and some trees . --AND-- some planes are parked in an airport surrounded by green meadows and some trees.
# False
# some planes are parked in an airport surrounded by green meadows and some trees . --AND-- some planes are parked in an airport surrounded by green meadows and some trees .
# True
# 3
# image index = 37
# sent index = 3
# some planes are in an airport near green meadows . --AND-- some planes are in an airport near green meadows.
# False
# some planes are in an airport near green meadows . --AND-- some planes are located at an airport near green meadows.
# False
# some planes are in an airport near green meadows . --AND-- some planes are located in an airport near the green meadows.
# False
# some planes are in an airport near green meadows . --AND-- some planes are in an airport near green meadows .
# True
# 3
# image index = 39
# sent index = 3
# white waves in green ocean are near a beach and meadows . --AND-- White waves in the green ocean are near a beach and meadows.
# False
# white waves in green ocean are near a beach and meadows . --AND-- White waves in green ocean are close to a beach and meadows.
# False
# white waves in green ocean are near a beach and meadows . --AND-- white waves in green ocean are close to a beach and meadows.
# False
# white waves in green ocean are near a beach and meadows . --AND-- white waves in green ocean are near a beach and meadows .
# True
# 3
# image index = 954
# sent index = 3
# it is a piece of yellow bareland . --AND-- It's a piece of yellow bare land.
# False
# it is a piece of yellow bareland . --AND-- It's a piece of yellow naked land.
# False
# it is a piece of yellow bareland . --AND-- It's a piece of yellow stripe.
# False
# it is a piece of yellow bareland . --AND-- it is a piece of yellow bareland .
# True
# 3
# image index = 505
# sent index = 3
# a piece of green ocean is near yellow beach and many green trees . --AND-- a piece of green ocean is near the yellow beach and many green trees.
# False
# a piece of green ocean is near yellow beach and many green trees . --AND-- a piece of green ocean is near the yellow beach and many green trees.
# False
# a piece of green ocean is near yellow beach and many green trees . --AND-- a piece of green ocean is near the yellow beach and many green trees.
# False
# a piece of green ocean is near yellow beach and many green trees . --AND-- a piece of green ocean is near yellow beach and many green trees .
# True
# 3
# image index = 975
# sent index = 3
# white waves in green ocean are near yellow beach . --AND-- White waves in the green ocean are near the yellow beach.
# False
# white waves in green ocean are near yellow beach . --AND-- White waves in the green ocean are near the yellow beach.
# False
# white waves in green ocean are near yellow beach . --AND-- white waves in green ocean are near yellow beach.
# False
# white waves in green ocean are near yellow beach . --AND-- white waves in green ocean are near yellow beach .
# True
# 3
# image index = 977
# sent index = 3
# some green spots are scattered in a piece of khaki bareland . --AND-- Some green spots are scattered in a piece of kaki nueland.
# False
# some green spots are scattered in a piece of khaki bareland . --AND-- Some green spots are scattered in a piece of naked khaki.
# False
# some green spots are scattered in a piece of khaki bareland . --AND-- Some green spots are scattered in a piece of khaki stripe.
# False
# some green spots are scattered in a piece of khaki bareland . --AND-- some green spots are scattered in a piece of khaki bareland .
# True
# 3
# image index = 490
# sent index = 3
# it is a piece of khaki bareland . --AND-- It's a piece of kaki nueland.
# False
# it is a piece of khaki bareland . --AND-- It's a piece of khaki bareland.
# False
# it is a piece of khaki bareland . --AND-- It's a piece of khaki stripping.
# False
# it is a piece of khaki bareland . --AND-- it is a piece of khaki bareland .
# True
# 3
# image index = 508
# sent index = 3
# a large piece of beach is between an ocean and some buildings . --AND-- a large part of the beach lies between an ocean and a few buildings.
# False
# a large piece of beach is between an ocean and some buildings . --AND-- a large part of the beach lies between an ocean and some buildings.
# False
# a large piece of beach is between an ocean and some buildings . --AND-- a large piece of beach lies between an ocean and some buildings.
# False
# a large piece of beach is between an ocean and some buildings . --AND-- a large piece of beach is between an ocean and some buildings .
# True
# 3
# image index = 953
# sent index = 3
# many wild roads are in a piece of khaki bareland . --AND-- Many wild roads are in a piece of kaki nueland.
# False
# many wild roads are in a piece of khaki bareland . --AND-- Many wild roads are in a piece of naked khaki.
# False
# many wild roads are in a piece of khaki bareland . --AND-- Many wild roads are in a piece of khaki stripping.
# False
# many wild roads are in a piece of khaki bareland . --AND-- many wild roads are in a piece of khaki bareland .
# True
# 3
# image index = 492
# sent index = 3
# it is a piece of yellow bareland . --AND-- It's a piece of yellow bare land.
# False
# it is a piece of yellow bareland . --AND-- It's a piece of yellow naked land.
# False
# it is a piece of yellow bareland . --AND-- It's a piece of yellow stripe.
# False
# it is a piece of yellow bareland . --AND-- it is a piece of yellow bareland .
# True
# 3
# image index = 425
# sent index = 3
# many planes are in an airport . --AND-- Many planes are in an airport.
# False
# many planes are in an airport . --AND-- A lot of planes are at an airport.
# False
# many planes are in an airport . --AND-- Many planes are at an airport.
# False
# many planes are in an airport . --AND-- many planes are in an airport .
# True
# 3
# image index = 40
# sent index = 3
# a piece of green ocean is next to yellow beach and near many green plants . --AND-- a piece of green ocean is next to the yellow beach and close to many green plants.
# False
# a piece of green ocean is next to yellow beach and near many green plants . --AND-- a piece of green ocean is next to the yellow beach and close to many green plants.
# False
# a piece of green ocean is next to yellow beach and near many green plants . --AND-- a piece of green ocean is close to the yellow beach and close to many green plants.
# False
# a piece of green ocean is next to yellow beach and near many green plants . --AND-- a piece of green ocean is next to yellow beach and near many green plants .
# True
# 3
# image index = 958
# sent index = 3
# several buildings are near a piece of bareland . --AND-- several buildings are near a bare piece of land.
# False
# several buildings are near a piece of bareland . --AND-- Several buildings are close to a piece of bare land.
# False
# several buildings are near a piece of bareland . --AND-- several buildings are close to a bare piece of land.
# False
# several buildings are near a piece of bareland . --AND-- several buildings are near a piece of bareland .
# True
# 3
# image index = 437
# sent index = 3
# waves in green ocean are near a yellow beach . --AND-- waves in the green ocean are near a yellow beach.
# False
# waves in green ocean are near a yellow beach . --AND-- waves in green ocean are near a yellow beach.
# False
# waves in green ocean are near a yellow beach . --AND-- waves in green ocean are near a yellow beach.
# False
# waves in green ocean are near a yellow beach . --AND-- waves in green ocean are near a yellow beach .
# True
# 3
# image index = 952
# sent index = 3
# many planes are parked in an airport . --AND-- Many aircraft are parked in an airport.
# False
# many planes are parked in an airport . --AND-- Many planes are parked at an airport.
# False
# many planes are parked in an airport . --AND-- Many planes are parked in an airport.
# False
# many planes are parked in an airport . --AND-- many planes are parked in an airport .
# True
# 3
# image index = 21
# sent index = 3
# it is a large piece of bareland . --AND-- It's a big piece of naked dirt.
# False
# it is a large piece of bareland . --AND-- It's a big piece of bare land.
# False
# it is a large piece of bareland . --AND-- It's a big piece of bare land.
# False
# it is a large piece of bareland . --AND-- it is a large piece of bareland .
# True
# 3
# image index = 439
# sent index = 3
# a beach is near an ocean with white waves . --AND-- a beach is close to an ocean with white waves.
# False
# a beach is near an ocean with white waves . --AND-- a beach is close to an ocean with white waves.
# False
# a beach is near an ocean with white waves . --AND-- a beach is near an ocean with white waves.
# False
# a beach is near an ocean with white waves . --AND-- a beach is near an ocean with white waves .
# True
# 3
# image index = 947
# sent index = 3
# it is a piece of yellow desert . --AND-- It's a piece of yellow desert.
# False
# it is a piece of yellow desert . --AND-- It's a piece of yellow desert.
# False
# it is a piece of yellow desert . --AND-- It's a piece of yellow desert.
# False
# it is a piece of yellow desert . --AND-- it is a piece of yellow desert .
# True
# 3
# image index = 486
# sent index = 3
# a piece of green ocean is near a yellow beach . --AND-- a piece of green ocean is near a yellow beach.
# False
# a piece of green ocean is near a yellow beach . --AND-- a piece of green ocean is near a yellow beach.
# False
# a piece of green ocean is near a yellow beach . --AND-- a piece of green ocean is near a yellow beach.
# False
# a piece of green ocean is near a yellow beach . --AND-- a piece of green ocean is near a yellow beach .
# True
# 3
# image index = 962
# sent index = 3
# it is a piece of khaki bareland . --AND-- It's a piece of kaki nueland.
# False
# it is a piece of khaki bareland . --AND-- It's a piece of khaki bareland.
# False
# it is a piece of khaki bareland . --AND-- It's a piece of khaki stripping.
# False
# it is a piece of khaki bareland . --AND-- it is a piece of khaki bareland .
# True
# 3
# image index = 516
# sent index = 3
# a beach is between an ocean with white waves and some green plants . --AND-- a beach is between an ocean with white waves and some green plants.
# False
# a beach is between an ocean with white waves and some green plants . --AND-- a beach lies between an ocean with white waves and some green plants.
# False
# a beach is between an ocean with white waves and some green plants . --AND-- a beach is located between an ocean with white waves and some green plants.
# False
# a beach is between an ocean with white waves and some green plants . --AND-- a beach is between an ocean with white waves and some green plants .
# True
# 3
# image index = 985
# sent index = 3
# some green trees are near a piece of bareland . --AND-- Some green trees are near a bare piece of land.
# False
# some green trees are near a piece of bareland . --AND-- Some green trees are near a bare piece of land.
# False
# some green trees are near a piece of bareland . --AND-- Some green trees are near a bare piece of land.
# False
# some green trees are near a piece of bareland . --AND-- some green trees are near a piece of bareland .
# True
# 3
# image index = 441
# sent index = 3
# a piece of yellow beach is between an ocean and farmlands . --AND-- a piece of yellow beach lies between an ocean and agricultural land.
# False
# a piece of yellow beach is between an ocean and farmlands . --AND-- a piece of yellow beach lies between an ocean and agricultural land.
# False
# a piece of yellow beach is between an ocean and farmlands . --AND-- a piece of yellow beach lies between an ocean and farmland.
# False
# a piece of yellow beach is between an ocean and farmlands . --AND-- a piece of yellow beach is between an ocean and farmlands .
# True
# 3
# image index = 941
# sent index = 3
# a road is near a piece of bareland . --AND-- A road is near a piece of bare land.
# False
# a road is near a piece of bareland . --AND-- a road is near a piece of bare land.
# False
# a road is near a piece of bareland . --AND-- a road is near a piece of bare land.
# False
# a road is near a piece of bareland . --AND-- a road is near a piece of bareland .
# True
# 3
# image index = 442
# sent index = 3
# some planes are parked in an airport near some green trees . --AND-- some planes are parked in an airport near some green trees.
# False
# some planes are parked in an airport near some green trees . --AND-- some planes are parked at an airport near some green trees.
# False
# some planes are parked in an airport near some green trees . --AND-- some planes are parked in an airport near some green trees.
# False
# some planes are parked in an airport near some green trees . --AND-- some planes are parked in an airport near some green trees .
# True
# 3
# image index = 48
# sent index = 3
# it is a piece of yellow bareland . --AND-- It's a piece of yellow bare land.
# False
# it is a piece of yellow bareland . --AND-- It's a piece of yellow naked land.
# False
# it is a piece of yellow bareland . --AND-- It's a piece of yellow stripe.
# False
# it is a piece of yellow bareland . --AND-- it is a piece of yellow bareland .
# True
# 3
# image index = 517
# sent index = 3
# it is a piece of bareland . --AND-- It's a piece of naked dirt.
# False
# it is a piece of bareland . --AND-- It's a piece of bare land.
# False
# it is a piece of bareland . --AND-- It's a piece of bare land.
# False
# it is a piece of bareland . --AND-- it is a piece of bareland .
# True
# 3
# image index = 429
# sent index = 3
# a row of white waves is between a beach and an ocean . --AND-- a row of white waves lies between a beach and an ocean.
# False
# a row of white waves is between a beach and an ocean . --AND-- a row of white waves lies between a beach and an ocean.
# False
# a row of white waves is between a beach and an ocean . --AND-- a row of white waves lies between a beach and an ocean.
# False
# a row of white waves is between a beach and an ocean . --AND-- a row of white waves is between a beach and an ocean .
# True
# 3
# image index = 940
# sent index = 3
# it is a large piece of bareland . --AND-- It's a big piece of naked dirt.
# False
# it is a large piece of bareland . --AND-- It's a big piece of bare land.
# False
# it is a large piece of bareland . --AND-- It's a big piece of bare land.
# False
# it is a large piece of bareland . --AND-- it is a large piece of bareland .
# True
# 3
# image index = 419
# sent index = 3
# it is a piece of yellow bareland . --AND-- It's a piece of yellow bare land.
# False
# it is a piece of yellow bareland . --AND-- It's a piece of yellow naked land.
# False
# it is a piece of yellow bareland . --AND-- It's a piece of yellow stripe.
# False
# it is a piece of yellow bareland . --AND-- it is a piece of yellow bareland .
# True
# 3
# image index = 494
# sent index = 3
# many white waves are in an ocean near a beach and some green trees . --AND-- many white waves are in an ocean near a beach and some green trees.
# False
# many white waves are in an ocean near a beach and some green trees . --AND-- many white waves are in an ocean near a beach and some green trees.
# False
# many white waves are in an ocean near a beach and some green trees . --AND-- Many white waves are in an ocean near a beach and some green trees.
# False
# many white waves are in an ocean near a beach and some green trees . --AND-- many white waves are in an ocean near a beach and some green trees .
# True
# 3
# image index = 986
# sent index = 3
# some planes are in an airport . --AND-- Some planes are in an airport.
# False
# some planes are in an airport . --AND-- Some planes are at an airport.
# False
# some planes are in an airport . --AND-- Some planes are at an airport.
# False
# some planes are in an airport . --AND-- some planes are in an airport .
# True
# 3
# image index = 49
# sent index = 3
# some planes are near a large building in an airport . --AND-- some planes are near a large building in an airport.
# False
# some planes are near a large building in an airport . --AND-- Some planes are close to a large building at an airport.
# False
# some planes are near a large building in an airport . --AND-- Some planes are close to a large building in an airport.
# False
# some planes are near a large building in an airport . --AND-- some planes are near a large building in an airport .
# True
# 3
# image index = 11
# sent index = 3
# a yellow beach is between an green ocean and green plants . --AND-- a yellow beach is between a green ocean and green plants.
# False
# a yellow beach is between an green ocean and green plants . --AND-- a yellow beach lies between a green ocean and green plants.
# False
# a yellow beach is between an green ocean and green plants . --AND-- a yellow beach lies between a green ocean and green plants.
# False
# a yellow beach is between an green ocean and green plants . --AND-- a yellow beach is between an green ocean and green plants .
# True
# 3
# image index = 939
# sent index = 3
# many planes are parked between two runways . --AND-- Many aircraft are parked between two runways.
# False
# many planes are parked between two runways . --AND-- Many planes are parked between two tracks.
# False
# many planes are parked between two runways . --AND-- Many planes are parked between two runways.
# False
# many planes are parked between two runways . --AND-- many planes are parked between two runways .
# True
# 3
# image index = 33
# sent index = 3
# it is a piece of khaki irregular bareland . --AND-- It's a piece of irregular khaki nueland.
# False
# it is a piece of khaki irregular bareland . --AND-- It's an irregular piece of naked caki.
# False
# it is a piece of khaki irregular bareland . --AND-- It's a piece of irregular caki stripping.
# False
# it is a piece of khaki irregular bareland . --AND-- it is a piece of khaki irregular bareland .
# True
# 3
# image index = 518
# sent index = 3
# several buildings are near a piece of bareland . --AND-- several buildings are near a bare piece of land.
# False
# several buildings are near a piece of bareland . --AND-- Several buildings are close to a piece of bare land.
# False
# several buildings are near a piece of bareland . --AND-- several buildings are close to a bare piece of land.
# False
# several buildings are near a piece of bareland . --AND-- several buildings are near a piece of bareland .
# True
# 3
# image index = 481
# sent index = 3
# a road is near a piece of bareland . --AND-- A road is near a piece of bare land.
# False
# a road is near a piece of bareland . --AND-- a road is near a piece of bare land.
# False
# a road is near a piece of bareland . --AND-- a road is near a piece of bare land.
# False
# a road is near a piece of bareland . --AND-- a road is near a piece of bareland .
# True
# 3
# image index = 418
# sent index = 3
# a piece of green ocean is near a yellow beach . --AND-- a piece of green ocean is near a yellow beach.
# False
# a piece of green ocean is near a yellow beach . --AND-- a piece of green ocean is near a yellow beach.
# False
# a piece of green ocean is near a yellow beach . --AND-- a piece of green ocean is near a yellow beach.
# False
# a piece of green ocean is near a yellow beach . --AND-- a piece of green ocean is near a yellow beach .
# True
# 3
# image index = 938
# sent index = 3
# many little green spots are in a piece of yellow bareland . --AND-- many small green spots are in a yellow bare piece of land.
# False
# many little green spots are in a piece of yellow bareland . --AND-- Many small green spots are in a piece of yellow naked land.
# False
# many little green spots are in a piece of yellow bareland . --AND-- Many small green spots are in a piece of yellow stripe.
# False
# many little green spots are in a piece of yellow bareland . --AND-- many little green spots are in a piece of yellow bareland .
# True
# 3
# image index = 501
# sent index = 3
# a piece of ocean is near a yellow beach and some meadows . --AND-- a piece of ocean is near a yellow beach and some meadows.
# False
# a piece of ocean is near a yellow beach and some meadows . --AND-- a piece of ocean is near a yellow beach and some meadows.
# False
# a piece of ocean is near a yellow beach and some meadows . --AND-- a piece of ocean is near a yellow beach and some meadows.
# False
# a piece of ocean is near a yellow beach and some meadows . --AND-- a piece of ocean is near a yellow beach and some meadows .
# True
# 3
# image index = 987
# sent index = 3
# it is a large piece of bareland . --AND-- It's a big piece of naked dirt.
# False
# it is a large piece of bareland . --AND-- It's a big piece of bare land.
# False
# it is a large piece of bareland . --AND-- It's a big piece of bare land.
# False
# it is a large piece of bareland . --AND-- it is a large piece of bareland .
# True
# 3
# image index = 417
# sent index = 3
# a yellow beach is between green trees and an ocean . --AND-- a yellow beach is between green trees and an ocean.
# False
# a yellow beach is between green trees and an ocean . --AND-- a yellow beach lies between green trees and an ocean.
# False
# a yellow beach is between green trees and an ocean . --AND-- a yellow beach lies between green trees and an ocean.
# False
# a yellow beach is between green trees and an ocean . --AND-- a yellow beach is between green trees and an ocean .
# True
# 3
# image index = 963
# sent index = 3
# a large piece of green ocean is near yellow beach . --AND-- a large piece of green ocean is located near the yellow beach.
# False
# a large piece of green ocean is near yellow beach . --AND-- a large piece of green ocean is near the yellow beach.
# False
# a large piece of green ocean is near yellow beach . --AND-- a large piece of green ocean is located near the yellow beach.
# False
# a large piece of green ocean is near yellow beach . --AND-- a large piece of green ocean is near yellow beach .
# True
# 3
# image index = 942
# sent index = 3
# many planes are in an airport surrounded by many buildings . --AND-- Many aircraft are located in an airport surrounded by many buildings.
# False
# many planes are in an airport surrounded by many buildings . --AND-- Many planes are located in an airport surrounded by many buildings.
# False
# many planes are in an airport surrounded by many buildings . --AND-- Many planes are in an airport surrounded by many buildings.
# False
# many planes are in an airport surrounded by many buildings . --AND-- many planes are in an airport surrounded by many buildings .
# True
# 3
# image index = 47
# sent index = 3
# several green trees are near a piece of bareland . --AND-- several green trees are near a bare piece of land.
# False
# several green trees are near a piece of bareland . --AND-- several green trees are near a bare piece of land.
# False
# several green trees are near a piece of bareland . --AND-- several green trees are located near a bare piece of land.
# False
# several green trees are near a piece of bareland . --AND-- several green trees are near a piece of bareland .
# True
# 3
# image index = 420
# sent index = 3
# it is a piece of yellow bareland . --AND-- It's a piece of yellow bare land.
# False
# it is a piece of yellow bareland . --AND-- It's a piece of yellow naked land.
# False
# it is a piece of yellow bareland . --AND-- It's a piece of yellow stripe.
# False
# it is a piece of yellow bareland . --AND-- it is a piece of yellow bareland .
# True
# 3
# image index = 515
# sent index = 3
# ...
# True
# 3
# image index = 100
# sent index = 3
# some small plants are around a rectangular bareland . --AND-- some small plants are around a rectangular bare earth.
# False
# some small plants are around a rectangular bareland . --AND-- some small plants are around a rectangular bare land.
# False
# some small plants are around a rectangular bareland . --AND-- some small plants are around a rectangular bare land.
# False
# some small plants are around a rectangular bareland . --AND-- some small plants are around a rectangular bareland .
# True
# 3
# image index = 363
# sent index = 3
# some planes are in an airport near some buildings and green trees . --AND-- some aircraft are located in an airport near some green buildings and trees.
# False
# some planes are in an airport near some buildings and green trees . --AND-- some planes are located at an airport near some buildings and green trees.
# False
# some planes are in an airport near some buildings and green trees . --AND-- some planes are located in an airport near some green buildings and trees.
# False
# some planes are in an airport near some buildings and green trees . --AND-- some planes are in an airport near some buildings and green trees .
# True
# 3
# image index = 99
# sent index = 3
# three baseball fields are near a river . --AND-- Three baseball grounds are near a river.
# False
# three baseball fields are near a river . --AND-- Three baseball fields are near a river.
# False
# three baseball fields are near a river . --AND-- Three baseball fields are near a river.
# False
# three baseball fields are near a river . --AND-- three baseball fields are near a river .
# True
# 3
# image index = 872
# sent index = 3
# some green trees are around a baseball field . --AND-- Some green trees are around a baseball pitch.
# False
# some green trees are around a baseball field . --AND-- Some green trees are around a baseball field.
# False
# some green trees are around a baseball field . --AND-- Some green trees are around a baseball field.
# False
# some green trees are around a baseball field . --AND-- some green trees are around a baseball field .
# True
# 3
# image index = 876
# sent index = 3
# this is a irregular bare land with some traces . --AND-- It's an irregular bare earth with a few traces.
# False
# this is a irregular bare land with some traces . --AND-- This is an irregular naked land with some traces.
# False
# this is a irregular bare land with some traces . --AND-- This is an irregular naked land with some traces.
# False
# this is a irregular bare land with some traces . --AND-- this is a irregular bare land with some traces .
# True
# 3
# image index = 365
# sent index = 3
# some green trees are around a baseball field . --AND-- Some green trees are around a baseball pitch.
# False
# some green trees are around a baseball field . --AND-- Some green trees are around a baseball field.
# False
# some green trees are around a baseball field . --AND-- Some green trees are around a baseball field.
# False
# some green trees are around a baseball field . --AND-- some green trees are around a baseball field .
# True
# 3
# image index = 877
# sent index = 3
# an airport runway extends to a black ocean . --AND-- an airport runway extends to a black ocean.
# False
# an airport runway extends to a black ocean . --AND-- A runway at the airport extends to a black ocean.
# False
# an airport runway extends to a black ocean . --AND-- an airport runway extends to a black ocean.
# False
# an airport runway extends to a black ocean . --AND-- an airport runway extends to a black ocean .
# True
# 3
# image index = 98
# sent index = 3
# several buildings are near a large piece of bareland . --AND-- several buildings are near a large piece of bare land.
# False
# several buildings are near a large piece of bareland . --AND-- several buildings are close to a large piece of bare land.
# False
# several buildings are near a large piece of bareland . --AND-- several buildings are close to a large piece of bare land.
# False
# several buildings are near a large piece of bareland . --AND-- several buildings are near a large piece of bareland .
# True
# 3
# image index = 366
# sent index = 3
# four baseball fields are surrounded by many green trees . --AND-- four baseball fields are surrounded by many green trees.
# False
# four baseball fields are surrounded by many green trees . --AND-- four baseball fields are surrounded by many green trees.
# False
# four baseball fields are surrounded by many green trees . --AND-- four baseball fields are surrounded by many green trees.
# False
# four baseball fields are surrounded by many green trees . --AND-- four baseball fields are surrounded by many green trees .
# True
# 3
# image index = 878
# sent index = 3
# many buildings are near an airport with some planes . --AND-- Many buildings are near an airport with a few planes.
# False
# many buildings are near an airport with some planes . --AND-- Many buildings are near an airport with some planes.
# False
# many buildings are near an airport with some planes . --AND-- Many buildings are close to an airport with some planes.
# False
# many buildings are near an airport with some planes . --AND-- many buildings are near an airport with some planes .
# True
# 3
# image index = 97
# sent index = 3
# some buildings are near a piece of bareland . --AND-- Some buildings are near a bare piece of land.
# False
# some buildings are near a piece of bareland . --AND-- Some buildings are close to a bare piece of land.
# False
# some buildings are near a piece of bareland . --AND-- Some buildings are close to a bare piece of land.
# False
# some buildings are near a piece of bareland . --AND-- some buildings are near a piece of bareland .
# True
# 3
# image index = 368
# sent index = 3
# here is an large area of bare land with some buildings and plants nearby . --AND-- Here is a large area of bare land with some buildings and plants nearby.
# False
# here is an large area of bare land with some buildings and plants nearby . --AND-- Here is a large surface of bare land with some buildings and plants nearby.
# False
# here is an large area of bare land with some buildings and plants nearby . --AND-- here is a large area of bare land with some buildings and plants nearby.
# False
# here is an large area of bare land with some buildings and plants nearby . --AND-- here is an large area of bare land with some buildings and plants nearby .
# True
# 3
# image index = 364
# sent index = 3
# an airport with a plane is near a large parking lot surrounded by green trees . --AND-- an airport with an airplane is close to a large parking lot surrounded by green trees.
# False
# an airport with a plane is near a large parking lot surrounded by green trees . --AND-- an airport with an airplane is close to a large parking lot surrounded by green trees.
# False
# an airport with a plane is near a large parking lot surrounded by green trees . --AND-- an airport with an airplane is close to a large parking lot surrounded by green trees.
# False
# an airport with a plane is near a large parking lot surrounded by green trees . --AND-- an airport with a plane is near a large parking lot surrounded by green trees .
# True
# 3
# image index = 358
# sent index = 3
# an airport is near a large piece of black water . --AND-- an airport is near a large piece of black water.
# False
# an airport is near a large piece of black water . --AND-- an airport is close to a large piece of black water.
# False
# an airport is near a large piece of black water . --AND-- an airport is close to a large piece of black water.
# False
# an airport is near a large piece of black water . --AND-- an airport is near a large piece of black water .
# True
# 3
# image index = 102
# sent index = 3
# many planes are parked in runways near many green trees . --AND-- Many aircraft are parked on runways near many green trees.
# False
# many planes are parked in runways near many green trees . --AND-- Many planes are parked on runways near many green trees.
# False
# many planes are parked in runways near many green trees . --AND-- Many planes are parked on runways near many green trees.
# False
# many planes are parked in runways near many green trees . --AND-- many planes are parked in runways near many green trees .
# True
# 3
# image index = 357
# sent index = 3
# many planes are parked in an airport . --AND-- Many aircraft are parked in an airport.
# False
# many planes are parked in an airport . --AND-- Many planes are parked at an airport.
# False
# many planes are parked in an airport . --AND-- Many planes are parked in an airport.
# False
# many planes are parked in an airport . --AND-- many planes are parked in an airport .
# True
# 3
# image index = 324
# sent index = 3
# many planes are parked in an airport . --AND-- Many aircraft are parked in an airport.
# False
# many planes are parked in an airport . --AND-- Many planes are parked at an airport.
# False
# many planes are parked in an airport . --AND-- Many planes are parked in an airport.
# False
# many planes are parked in an airport . --AND-- many planes are parked in an airport .
# True
# 3
# image index = 328
# sent index = 3
# many planes are in an airport . --AND-- Many planes are in an airport.
# False
# many planes are in an airport . --AND-- A lot of planes are at an airport.
# False
# many planes are in an airport . --AND-- Many planes are at an airport.
# False
# many planes are in an airport . --AND-- many planes are in an airport .
# True
# 3
# image index = 116
# sent index = 3
# many planes are parked in an airport . --AND-- Many aircraft are parked in an airport.
# False
# many planes are parked in an airport . --AND-- Many planes are parked at an airport.
# False
# many planes are parked in an airport . --AND-- Many planes are parked in an airport.
# False
# many planes are parked in an airport . --AND-- many planes are parked in an airport .
# True
# 3
# image index = 329
# sent index = 3
# some planes are parked in an airport . --AND-- some planes are parked in an airport.
# False
# some planes are parked in an airport . --AND-- Some planes are parked at an airport.
# False
# some planes are parked in an airport . --AND-- some planes are parked in an airport.
# False
# some planes are parked in an airport . --AND-- some planes are parked in an airport .
# True
# 3
# image index = 335
# sent index = 3
# some planes are parked in an airport . --AND-- some planes are parked in an airport.
# False
# some planes are parked in an airport . --AND-- Some planes are parked at an airport.
# False
# some planes are parked in an airport . --AND-- some planes are parked in an airport.
# False
# some planes are parked in an airport . --AND-- some planes are parked in an airport .
# True
# 3
# image index = 338
# sent index = 3
# many planes are in an airport . --AND-- Many planes are in an airport.
# False
# many planes are in an airport . --AND-- A lot of planes are at an airport.
# False
# many planes are in an airport . --AND-- Many planes are at an airport.
# False
# many planes are in an airport . --AND-- many planes are in an airport .
# True
# 3
# image index = 107
# sent index = 3
# some planes are parked in an airport . --AND-- some planes are parked in an airport.
# False
# some planes are parked in an airport . --AND-- Some planes are parked at an airport.
# False
# some planes are parked in an airport . --AND-- some planes are parked in an airport.
# False
# some planes are parked in an airport . --AND-- some planes are parked in an airport .
# True
# 3
# image index = 339
# sent index = 3
# several planes are in an airport with buildings . --AND-- several planes are in an airport with buildings.
# False
# several planes are in an airport with buildings . --AND-- several planes are at an airport with buildings.
# False
# several planes are in an airport with buildings . --AND-- Several planes are at an airport with buildings.
# False
# several planes are in an airport with buildings . --AND-- several planes are in an airport with buildings .
# True
# 3
# image index = 106
# sent index = 3
# many planes are parked in an airport . --AND-- Many aircraft are parked in an airport.
# False
# many planes are parked in an airport . --AND-- Many planes are parked at an airport.
# False
# many planes are parked in an airport . --AND-- Many planes are parked in an airport.
# False
# many planes are parked in an airport . --AND-- many planes are parked in an airport .
# True
# 3
# image index = 347
# sent index = 3
# many planes are in a large airport . --AND-- Many planes are in a large airport.
# False
# many planes are in a large airport . --AND-- Many planes are located at a large airport.
# False
# many planes are in a large airport . --AND-- A lot of planes are in a big airport.
# False
# many planes are in a large airport . --AND-- many planes are in a large airport .
# True
# 3
# image index = 105
# sent index = 3
# some planes are parked in an airport . --AND-- some planes are parked in an airport.
# False
# some planes are parked in an airport . --AND-- Some planes are parked at an airport.
# False
# some planes are parked in an airport . --AND-- some planes are parked in an airport.
# False
# some planes are parked in an airport . --AND-- some planes are parked in an airport .
# True
# 3
# image index = 350
# sent index = 3
# many planes are in an airport . --AND-- Many planes are in an airport.
# False
# many planes are in an airport . --AND-- A lot of planes are at an airport.
# False
# many planes are in an airport . --AND-- Many planes are at an airport.
# False
# many planes are in an airport . --AND-- many planes are in an airport .
# True
# 3
# image index = 104
# sent index = 3
# many planes are parked in an airport . --AND-- Many aircraft are parked in an airport.
# False
# many planes are parked in an airport . --AND-- Many planes are parked at an airport.
# False
# many planes are parked in an airport . --AND-- Many planes are parked in an airport.
# False
# many planes are parked in an airport . --AND-- many planes are parked in an airport .
# True
# 3
# image index = 352
# sent index = 3
# several green trees are around a baseball field . --AND-- several green trees are around a baseball pitch.
# False
# several green trees are around a baseball field . --AND-- several green trees are around a baseball field.
# False
# several green trees are around a baseball field . --AND-- several green trees are around a baseball field.
# False
# several green trees are around a baseball field . --AND-- several green trees are around a baseball field .
# True
# 3
# image index = 869
# sent index = 3
# many planes are parked in an airport . --AND-- Many aircraft are parked in an airport.
# False
# many planes are parked in an airport . --AND-- Many planes are parked at an airport.
# False
# many planes are parked in an airport . --AND-- Many planes are parked in an airport.
# False
# many planes are parked in an airport . --AND-- many planes are parked in an airport .
# True
# 3
# image index = 354
# sent index = 3
# many planes are in an airport near many green trees . --AND-- Many planes are in an airport near many green trees.
# False
# many planes are in an airport near many green trees . --AND-- Many planes are located in an airport near many green trees.
# False
# many planes are in an airport near many green trees . --AND-- Many planes are in an airport near many green trees.
# False
# many planes are in an airport near many green trees . --AND-- many planes are in an airport near many green trees .
# True
# 3
# image index = 103
# sent index = 3
# it is a large piece of bareland . --AND-- It's a big piece of naked dirt.
# False
# it is a large piece of bareland . --AND-- It's a big piece of bare land.
# False
# it is a large piece of bareland . --AND-- It's a big piece of bare land.
# False
# it is a large piece of bareland . --AND-- it is a large piece of bareland .
# True
# 3
# image index = 640
# sent index = 3
# white waves are between yellow beach and green ocean . --AND-- The white waves are between the yellow beach and the green ocean.
# False
# white waves are between yellow beach and green ocean . --AND-- the white waves are between the yellow beach and the green ocean.
# False
# white waves are between yellow beach and green ocean . --AND-- The white waves are between the yellow beach and the green ocean.
# False
# white waves are between yellow beach and green ocean . --AND-- white waves are between yellow beach and green ocean .
# True
# 3
# image index = 999
# sent index = 3

# %%
text_augmented_ds['images'][0]
# Out:
# {'filename': 'airport_1.jpg',
#  'imgid': 0,
#  'sentences': [{'imgid': 0,
#    'raw': 'Many aircraft are parked next to a long building in an airport.',
#    'sentid': 0,
#    'tokens': ['many',
#     'planes',
#     'are',
#     'parked',
#     'next',
#     'to',
#     'a',
#     'long',
#     'building',
#     'in',
#     'an',
#     'airport']},
#   {'imgid': 0,
#    'raw': 'Many planes are parked next to a long building at an airport.',
#    'sentid': 1,
#    'tokens': ['many',
#     'planes',
#     'are',
#     'parked',
#     'next',
#     'to',
#     'a',
#     'long',
#     'building',
#     'in',
#     'an',
#     'airport']},
#   {'imgid': 0,
#    'raw': 'Many planes are parked next to a long building in an airport.',
#    'sentid': 2,
#    'tokens': ['many',
#     'planes',
#     'are',
#     'parked',
#     'next',
#     'to',
#     'a',
#     'long',
#     'building',
#     'in',
#     'an',
#     'airport']},
#   {'imgid': 0,
#    'raw': 'many planes are parked next to a long building at an airport.',
#    'sentid': 3,
#    'tokens': ['many',
#     'planes',
#     'are',
#     'parked',
#     'next',
#     'to',
#     'a',
#     'long',
#     'building',
#     'in',
#     'an',
#     'airport']},
#   {'imgid': 0,
#    'raw': 'many planes are parked next to a long building in an airport .',
#    'sentid': 4,
#    'tokens': ['many',
#     'planes',
#     'are',
#     'parked',
#     'next',
#     'to',
#     'a',
#     'long',
#     'building',
#     'in',
#     'an',
#     'airport']}],
#  'sentids': [0, 1, 2, 3, 4],
#  'split': 'train'}

# %%
sentences_with_translation_df.head()
# Out:
#      image_id  ...                           back_translated_sentence
# 740       928  ...  seawater is so transparent that it looks like ...
# 741       584  ...         many cars parked on the side of the earth.
# 742       938  ...     a piece of green ocean is near a yellow beach.
# 743       570  ...      some plants are near a piece of kaki nueland.
# 744       599  ...         The bare earth has a small piece of water.
#
# [5 rows x 5 columns]

# %%
sentences_with_translation_df[sentences_with_translation_df.sentence ==  'many planes are parked next to a long building in an airport .']
# Out:
#       image_id  ...                           back_translated_sentence
# 1396         0  ...  Many aircraft are parked next to a long buildi...
# 677          0  ...  Many planes are parked next to a long building...
# 2013         0  ...  Many planes are parked next to a long building...
# 2586         0  ...  many planes are parked next to a long building...
#
# [4 rows x 5 columns]
